# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. 데이터 확인하기

# %%
sgd_data = pd.read_csv("/content/drive/MyDrive/CNN_master/오수진/write_test_SGD.csv")
RMSprop_data = pd.read_csv("/content/drive/MyDrive/CNN_master/오수진/write_tets_RMSprop.csv")
Adagrad_data = pd.read_csv("/content/drive/MyDrive/CNN_master/오수진/write_tets_Adagrad.csv")
Momentum_data = pd.read_csv("/content/drive/MyDrive/CNN_master/오수진/write_tets_Momentum.csv")
Adam_data = pd.read_csv("/content/drive/MyDrive/CNN_master/오수진/dataset/write_tets_Adam.csv")

# %%
df_sgd = pd.DataFrame(sgd_data)
df_RMSprop = pd.DataFrame(RMSprop_data)
df_Adagrad = pd.DataFrame(Adagrad_data)
df_Momentum = pd.DataFrame(Momentum_data)
df_Adam = pd.DataFrame(Adam_data)

# %%
df_sgd[2:7]
# Out:
#    start_filters  Res_set_num  ... val_accuracy  val_loss
# 2  [ 32  32 128]            3  ...     0.776748  0.792480
# 3  [ 32  32 128]            3  ...     0.753326  0.867683
# 4  [ 32  32 128]            3  ...     0.816748  0.654104
# 5  [ 32  32 128]            3  ...     0.791328  0.748892
# 6  [ 32  32 128]            3  ...     0.770074  0.801072
#
# [5 rows x 17 columns]

# %%
df_sgd.shape[0]+df_RMSprop.shape[0]+df_Adagrad.shape[0]+df_Momentum.shape[0]+df_Adam.shape[0]
# Out:
# 248

# %% [markdown]
# # 2. Top 5

# %%
df_sort_sgd = df_sgd.sort_values(by=["test_accuracy"], ascending=[False])
df_sort_RMSprop = df_RMSprop.sort_values(by=["test_accuracy"], ascending=[False])
df_sort_Adagrad = df_Adagrad.sort_values(by=["test_accuracy"], ascending=[False])
df_sort_Momentum = df_Momentum.sort_values(by=["test_accuracy"], ascending=[False])
df_sort_Adam = df_Adam.sort_values(by=["test_accuracy"], ascending=[False])

# %%
df_sort_sgd[['start_filters','Res_set_num','identity_L_num','DO','opt','momentum_rate','lr','EPOCHS','train_accuracy','test_accuracy','test_loss','train_loss','val_accuracy','val_loss']][:5]
# Out:
#     start_filters  Res_set_num  ... val_accuracy  val_loss
# 21  [ 64  64 256]            4  ...     0.953071  0.240214
# 15  [ 64  64 256]            3  ...     0.978788  0.133185
# 24  [ 64  64 256]            4  ...     0.964846  0.212455
# 16  [ 64  64 256]            3  ...     0.979936  0.119495
# 20  [ 64  64 256]            4  ...     0.958130  0.257031
#
# [5 rows x 14 columns]

# %% [markdown]
# 1) start_filters = [64 64 256]
# 2) Drop out = 0.2
# 3) lr = 0.01
#
# 위와 같은 경우에 가장 높은 성능을 보였습니다.

# %%
df_sort_RMSprop[['start_filters','Res_set_num','identity_L_num','DO','opt','momentum_rate','lr','EPOCHS','train_accuracy','test_accuracy','test_loss','train_loss','val_accuracy','val_loss']][:5]
# Out:
#     start_filters  Res_set_num  ... val_accuracy  val_loss
# 1   [ 32  32 128]            3  ...     0.976728  0.091126
# 18  [ 64  64 256]            4  ...     0.975261  0.099862
# 23  [ 64  64 256]            4  ...     0.970862  0.120172
# 10  [ 32  32 128]            4  ...     0.976983  0.095196
# 14  [ 64  64 256]            3  ...     0.973412  0.099040
#
# [5 rows x 14 columns]

# %%
df_sort_RMSprop[['test_accuracy']].mean()
# Out:
# test_accuracy    0.873692
# dtype: float64

# %%
df_sort_RMSprop[['start_filters','Res_set_num','identity_L_num','DO','opt','momentum_rate','lr','EPOCHS','train_accuracy','test_accuracy','test_loss','train_loss','val_accuracy','val_loss']][:10]
# Out:
#     start_filters  Res_set_num  ... val_accuracy  val_loss
# 1   [ 32  32 128]            3  ...     0.976728  0.091126
# 18  [ 64  64 256]            4  ...     0.975261  0.099862
# 23  [ 64  64 256]            4  ...     0.970862  0.120172
# 10  [ 32  32 128]            4  ...     0.976983  0.095196
# 14  [ 64  64 256]            3  ...     0.973412  0.099040
# 21  [ 64  64 256]            4  ...     0.975963  0.103612
# 13  [ 64  64 256]            3  ...     0.966590  0.135705
# 46  [ 64  64 256]            4  ...     0.969141  0.113301
# 35  [ 32  32 128]            4  ...     0.969969  0.125668
# 43  [ 64  64 256]            4  ...     0.969141  0.113823
#
# [10 rows x 14 columns]

# %%
df_sort_Adagrad[['start_filters','Res_set_num','identity_L_num','DO','opt','momentum_rate','lr','EPOCHS','train_accuracy','test_accuracy','test_loss','train_loss','val_accuracy','val_loss']][:5]
# Out:
#     start_filters  Res_set_num  ... val_accuracy  val_loss
# 2   [ 32  32 128]            3  ...     0.974241  0.108252
# 13  [ 64  64 256]            3  ...     0.976855  0.083794
# 20  [ 64  64 256]            4  ...     0.972839  0.106818
# 3   [ 32  32 128]            3  ...     0.972775  0.112208
# 9   [ 32  32 128]            4  ...     0.971308  0.115343
#
# [5 rows x 14 columns]

# %%
df_sort_Momentum[['start_filters','Res_set_num','identity_L_num','DO','opt','momentum_rate','lr','EPOCHS','train_accuracy','test_accuracy','test_loss','train_loss','val_accuracy','val_loss']][:10]
# Out:
#     start_filters  Res_set_num  ... val_accuracy  val_loss
# 41  [ 64  64 256]            3  ...     0.981701  0.070157
# 14  [ 64  64 256]            3  ...     0.982785  0.062032
# 37  [ 64  64 256]            3  ...     0.971372  0.104069
# 45  [ 64  64 256]            4  ...     0.982402  0.067960
# 17  [ 64  64 256]            3  ...     0.977238  0.085435
# 40  [ 64  64 256]            3  ...     0.974624  0.096339
# 42  [ 64  64 256]            4  ...     0.980553  0.069907
# 13  [ 64  64 256]            3  ...     0.978641  0.086622
# 12  [ 64  64 256]            3  ...     0.969459  0.104347
# 39  [ 64  64 256]            3  ...     0.978067  0.082107
#
# [10 rows x 14 columns]

# %%
df_sort_Adam[['start_filters','Res_set_num','identity_L_num','DO','opt','momentum_rate','lr','EPOCHS','train_accuracy','test_accuracy','test_loss','train_loss','val_accuracy','val_loss']][:5]
# Out:
#     start_filters  Res_set_num  ... val_accuracy  val_loss
# 17  [ 64  64 256]            3  ...     0.996982  0.010544
# 14  [ 64  64 256]            3  ...     0.994644  0.015736
# 23  [ 64  64 256]            4  ...     0.996642  0.013389
# 21  [ 64  64 256]            4  ...     0.994304  0.018709
# 18  [ 64  64 256]            4  ...     0.996812  0.010208
#
# [5 rows x 14 columns]
